# %% [markdown]
# ## The channel's performance in terms of likes and comments has been increasing recently, which coincides with a decrease in video duration.

# %% [markdown]
# ## It seems like this is a favorable path the channel can take.

# %%
#

# %%
#

# %%
#

# %% [markdown]
# ## The following are the videos that are most likely to cause debate, the following has the highest comment per view ratio.

# %% [markdown]
# ### As you can see the videos are mostly about religion or women rights, the channel can produce more content about these topics if comments is what it's after.

# %%
#
# Out:
#                                                      0
# title
# بي_بي_سي_ترندينغ |  " مكاني ليس في المطبخ" شعار...   0
# بي بي سي عربي: حلقة دنيانا (202): ملحدون عكس ال...   1
# بي_بي_سي_ترندينغ | #بالفيديو: #فرحات_مهني يحدث ...   2
# ما رأي الدين الإسلامي في الاغتصاب الزوجي؟            3
# ملكة جمال العراق تزور صديقتها ملكة جمال إسرائيل      4
# بي_بي_سي_ترندينغ | هل سيصبح الإلحاد جريمة في #مصر؟   5
# بي_بي_سي_ترندينغ | #مش_بالسيف حملة في #تونس مطا...   6
# بي_بي_سي_ترندينغ | #منقبة تمنع للمرة الثانية من...   7
# أسرة مترابطة:  الأم مسيحية والأب مسلم                8
# بي_بي_سي_ترندينغ:  مطالبات لإبطال سور من #القرآ...   9
# هل تنضمّ دول جديدة إلى جامعة الدول العربيّة؟- ج...  10
# الملحدون في السعودية - السعوديون والحرية            11
# بي_بي_سي_ترندينغ:  #الكسكس...طبق مغربي أم جزائر...  12
# هل تشعر المسلمات بالخجل عند الجهر بإفطارهن في #...  13
# مخاوف من اندثار اللغة الآرامية                      14
# هل سيفاجئ المنتخب السعودي العالم ؟                  15
# ...

# %% [markdown]
# ## The following are very common words in the titles, videos about iraq for example cause alot of debate, and videos about the world gathers views

# %%
#

# %% [markdown]
# # The following is a comparison between video Durations.
# # medium length videos are better in all respects, except for likes count , where short videos dominate

# %% [markdown]
# ### short : less than 16 minutes. medium: between 16 and 50 minutes, long : more than 50 minutes

# %% [markdown]
# # Another comparison of different video lengths on more dimensions

# %%
#
